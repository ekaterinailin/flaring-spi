# %%
import matplotlib.pyplot as plt
from funcs.notebook import *

# %%
df = pd.read_csv("../results/plots/nan_AUMic_AD_Test_cumdist_total_Both Sectors_Orbit_shift0.0.csv")

# %%
# %matplotlib inline
plt.figure(figsize=(7, 5.5))

plt.plot([0,1],[0,1],c="grey", linestyle="dotted", label="uniform distribution")
# plt.scatter(df.phase, df.exp_cum, s=10, c="k", marker="d", label="expected distribution")
plt.scatter(df.phase, df.meas_cum, s=15, marker="x",c="g", label="measured distribution")
plt.plot(df.phase, df.exp_cum, label="expected distribution", zorder=-10, c="b");

plt.xlim(0,1)
plt.ylim(0,1)
plt.legend(loc=2, frameon=False, fontsize=15)
plt.xlabel("orbital phase", fontsize=15)
plt.ylabel("cumul. fraction of observed flares", fontsize=15)
plt.tight_layout()
plt.savefig("/home/ekaterina/Documents/002_writing/aumic-flaring-spi-draft/"
            "figures/2021_12_15_AUMic_cumdist_orbit_fullsample_shift00.png",dpi=300)
