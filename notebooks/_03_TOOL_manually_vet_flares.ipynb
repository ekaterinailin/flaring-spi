# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from astropy.io import fits

# %%
ff = pd.read_csv("../results/2022_07_flares_vetted.csv")
ff_to_fill = pd.read_csv("../results/2022_07_flares.csv")
ff.shape, ff_to_fill.shape
# Out:
# ((14596, 23), (15926, 22))

# %%
g = lambda x: f"{x.ID}_{x.mission}_{x.qcs}"
ff["helpid"] = ff.apply(g, axis=1)
ff_to_fill["helpid"] = ff_to_fill.apply(g, axis=1)

# %%
ids_searched = set(list(ff_to_fill.groupby('helpid').indices.keys()))
ids_vetted = set(list(ff.groupby('helpid').indices.keys()))
ids_to_add = list(ids_searched-ids_vetted)

# %%
ids_to_add
# Out:
# ['KOI-2174_Kepler_13',
#  'KOI-2174_Kepler_17',
#  'KOI-2760_Kepler_16',
#  'KOI-2760_Kepler_15',
#  'KOI-2760_Kepler_13',
#  'KOI-2174_Kepler_15',
#  'KOI-2174_Kepler_16',
#  'KOI-2174_Kepler_14',
#  'KOI-2174_Kepler_12',
#  'KOI-2760_Kepler_14']

# %%
ff_to_add = ff_to_fill[ff_to_fill.helpid.isin(ids_to_add)]
ff_to_add
# Out:
#         istart    istop     cstart      cstop       tstart        tstop  \
# 15901      NaN      NaN        NaN        NaN          NaN          NaN
# 15902  24500.0  24503.0  1507270.0  1507273.0  1143.411908  1143.413951
# 15903  32365.0  32368.0  1563389.0  1563392.0  1181.635953  1181.637997
# 15904      NaN      NaN        NaN        NaN          NaN          NaN
# 15905  42598.0  42601.0  2057276.0  2057279.0  1518.031941  1518.033984
# 15906      NaN      NaN        NaN        NaN          NaN          NaN
# 15907      NaN      NaN        NaN        NaN          NaN          NaN
# 15908      NaN      NaN        NaN        NaN          NaN          NaN
# 15909      NaN      NaN        NaN        NaN          NaN          NaN
# 15910      NaN      NaN        NaN        NaN          NaN          NaN
# 15911      NaN      NaN        NaN        NaN          NaN          NaN
# 15912      NaN      NaN        NaN        NaN          NaN          NaN
# 15913      NaN      NaN        NaN        NaN          NaN          NaN
# 15914    488.0    496.0  1792219.0  1792227.0  1337.501726  1337.507174
# 15915      NaN      NaN        NaN        NaN          NaN          NaN
# 15916      NaN      NaN        NaN        NaN          NaN          NaN
# 15917      NaN      NaN        NaN        NaN          NaN          NaN
# 15918  23250.0  23253.0  1637057.0  1637060.0  1231.815406  1231.817450
# 15919      NaN      NaN        NaN        NaN          NaN          NaN
# 15920  24818.0  24821.0  1771090.0  1771093.0  1323.110093  1323.112136
# 15921    489.0    496.0  1792220.0  1792227.0  1337.502067  1337.506835
# 15922      NaN      NaN        NaN        NaN          NaN          NaN
# 15923      NaN      NaN        NaN        NaN          NaN          NaN
# 15924      NaN      NaN        NaN        NaN          NaN          NaN
# 15925  39511.0  39514.0  2054148.0  2054151.0  1515.901711  1515.903755
#
#           ed_rec  ed_rec_err  ampl_rec       dur  ...        TIC  qcs mission  \
# 15901        NaN         NaN       NaN       NaN  ...  239291510   12  Kepler
# 15902   7.612817    0.305495  0.063724  0.002043  ...  239291510   12  Kepler
# 15903   3.350767    0.516903  0.019318  0.002043  ...  239291510   12  Kepler
# 15904        NaN         NaN       NaN       NaN  ...  239291510   16  Kepler
# 15905  16.872834    0.332515  0.145777  0.002043  ...  239291510   16  Kepler
# 15906        NaN         NaN       NaN       NaN  ...  239291510   16  Kepler
# 15907        NaN         NaN       NaN       NaN  ...  239291510   15  Kepler
# 15908        NaN         NaN       NaN       NaN  ...  239291510   15  Kepler
# 15909        NaN         NaN       NaN       NaN  ...  239291510   15  Kepler
# 15910        NaN         NaN       NaN       NaN  ...  239291510   17  Kepler
# 15911        NaN         NaN       NaN       NaN  ...  239291510   17  Kepler
# 15912        NaN         NaN       NaN       NaN  ...  239291510   14  Kepler
# 15913        NaN         NaN       NaN       NaN  ...  239291510   14  Kepler
# 15914  19.329736    0.499692  0.063426  0.005449  ...  239291510   14  Kepler
# 15915        NaN         NaN       NaN       NaN  ...  239291510   13  Kepler
# 15916        NaN         NaN       NaN       NaN  ...  239291510   13  Kepler
# 15917        NaN         NaN       NaN       NaN  ...  239291510   13  Kepler
# 15918   1.563752    0.138209  0.011428  0.002043  ...  158219569   13  Kepler
# 15919        NaN         NaN       NaN       NaN  ...  158219569   14  Kepler
# 15920   3.557333    0.160248  0.026955  0.002043  ...  158219569   14  Kepler
# 15921   5.753900    0.230500  0.024226  0.004768  ...  158219569   14  Kepler
# 15922        NaN         NaN       NaN       NaN  ...  158219569   15  Kepler
# 15923        NaN         NaN       NaN       NaN  ...  158219569   15  Kepler
# 15924        NaN         NaN       NaN       NaN  ...  158219569   15  Kepler
# 15925   1.462742    0.155396  0.012463  0.002043  ...  158219569   16  Kepler
#
#            tstamp  lc_n      w mask_pos_outliers_sigma  real  note  \
# 15901  2022_08_17     1  123.0                     2.5  -1.0   NaN
# 15902  2022_08_17     1  123.0                     2.5   NaN   NaN
# 15903  2022_08_17     1  123.0                     2.5   NaN   NaN
# 15904  2022_08_17    15  123.0                     2.5  -1.0   NaN
# 15905  2022_08_17    15  123.0                     2.5   NaN   NaN
# 15906  2022_08_17    15  123.0                     2.5  -1.0   NaN
# 15907  2022_08_17    12  123.0                     2.5  -1.0   NaN
# 15908  2022_08_17    12  123.0                     2.5  -1.0   NaN
# 15909  2022_08_17    12  123.0                     2.5  -1.0   NaN
# 15910  2022_08_17    16  123.0                     2.5  -1.0   NaN
# 15911  2022_08_17    16  123.0                     2.5  -1.0   NaN
# 15912  2022_08_17     9  125.0                     2.5  -1.0   NaN
# 15913  2022_08_17     9  123.0                     2.5  -1.0   NaN
# 15914  2022_08_17     9  123.0                     2.5   NaN   NaN
# 15915  2022_08_17     6  123.0                     2.5  -1.0   NaN
# 15916  2022_08_17     6  123.0                     2.5  -1.0   NaN
# 15917  2022_08_17     6  123.0                     2.5  -1.0   NaN
# 15918  2022_08_17     1  123.0                     2.5   NaN   NaN
# 15919  2022_08_17     2  125.0                     2.5  -1.0   NaN
# 15920  2022_08_17     2  123.0                     2.5   NaN   NaN
# 15921  2022_08_17     2  123.0                     2.5   NaN   NaN
# 15922  2022_08_17     5  123.0                     2.5  -1.0   NaN
# 15923  2022_08_17     5  123.0                     2.5  -1.0   NaN
# 15924  2022_08_17     5  123.0                     2.5  -1.0   NaN
# 15925  2022_08_17     8  123.0                     2.5   NaN   NaN
#
#                    helpid
# 15901  KOI-2174_Kepler_12
# 15902  KOI-2174_Kepler_12
# 15903  KOI-2174_Kepler_12
# 15904  KOI-2174_Kepler_16
# 15905  KOI-2174_Kepler_16
# 15906  KOI-2174_Kepler_16
# 15907  KOI-2174_Kepler_15
# 15908  KOI-2174_Kepler_15
# 15909  KOI-2174_Kepler_15
# 15910  KOI-2174_Kepler_17
# 15911  KOI-2174_Kepler_17
# 15912  KOI-2174_Kepler_14
# 15913  KOI-2174_Kepler_14
# 15914  KOI-2174_Kepler_14
# 15915  KOI-2174_Kepler_13
# 15916  KOI-2174_Kepler_13
# 15917  KOI-2174_Kepler_13
# 15918  KOI-2760_Kepler_13
# 15919  KOI-2760_Kepler_14
# 15920  KOI-2760_Kepler_14
# 15921  KOI-2760_Kepler_14
# 15922  KOI-2760_Kepler_15
# 15923  KOI-2760_Kepler_15
# 15924  KOI-2760_Kepler_15
# 15925  KOI-2760_Kepler_16
#
# [25 rows x 23 columns]

# %%
ff_new = ff.append(ff_to_add)
ff_new.iloc[ff.shape[0]-5:ff.shape[0]+5]
# Out:
#         istart    istop     cstart      cstop       tstart        tstop  \
# 14591    127.0    154.0  1989977.0  1990004.0  1472.193957  1472.212347
# 14592    161.0    504.0  1990011.0  1990354.0  1472.217114  1472.450731
# 14593    550.0    553.0  1990400.0  1990403.0  1472.482062  1472.484105
# 14594      NaN      NaN        NaN        NaN          NaN          NaN
# 14595   5476.0   5479.0  2074662.0  2074665.0  1529.874051  1529.876094
# 15901      NaN      NaN        NaN        NaN          NaN          NaN
# 15902  24500.0  24503.0  1507270.0  1507273.0  1143.411908  1143.413951
# 15903  32365.0  32368.0  1563389.0  1563392.0  1181.635953  1181.637997
# 15904      NaN      NaN        NaN        NaN          NaN          NaN
# 15905  42598.0  42601.0  2057276.0  2057279.0  1518.031941  1518.033984
#
#           ed_rec  ed_rec_err  ampl_rec       dur  ...        TIC  qcs mission  \
# 14591   0.953730    0.043598  0.000841  0.018390  ...   63368895   16  Kepler
# 14592  14.704569    0.019728  0.001259  0.233617  ...   63368895   16  Kepler
# 14593   0.137316    0.024629  0.000833  0.002043  ...   63368895   16  Kepler
# 14594        NaN         NaN       NaN       NaN  ...   63368895   16  Kepler
# 14595   0.067480    0.011629  0.000436  0.002043  ...   63368895   16  Kepler
# 15901        NaN         NaN       NaN       NaN  ...  239291510   12  Kepler
# 15902   7.612817    0.305495  0.063724  0.002043  ...  239291510   12  Kepler
# 15903   3.350767    0.516903  0.019318  0.002043  ...  239291510   12  Kepler
# 15904        NaN         NaN       NaN       NaN  ...  239291510   16  Kepler
# 15905  16.872834    0.332515  0.145777  0.002043  ...  239291510   16  Kepler
#
#            tstamp  lc_n      w mask_pos_outliers_sigma  real  note  \
# 14591  2022_08_16     8  123.0                     2.5   0.0   NaN
# 14592  2022_08_16     8  123.0                     2.5   0.0   NaN
# 14593  2022_08_16     8  123.0                     2.5   0.0   NaN
# 14594  2022_08_16     8  123.0                     2.5  -1.0   NaN
# 14595  2022_08_16     8  123.0                     2.5   0.0   NaN
# 15901  2022_08_17     1  123.0                     2.5  -1.0   NaN
# 15902  2022_08_17     1  123.0                     2.5   NaN   NaN
# 15903  2022_08_17     1  123.0                     2.5   NaN   NaN
# 15904  2022_08_17    15  123.0                     2.5  -1.0   NaN
# 15905  2022_08_17    15  123.0                     2.5   NaN   NaN
#
#                    helpid
# 14591  KOI-2687_Kepler_16
# 14592  KOI-2687_Kepler_16
# 14593  KOI-2687_Kepler_16
# 14594  KOI-2687_Kepler_16
# 14595  KOI-2687_Kepler_16
# 15901  KOI-2174_Kepler_12
# 15902  KOI-2174_Kepler_12
# 15903  KOI-2174_Kepler_12
# 15904  KOI-2174_Kepler_16
# 15905  KOI-2174_Kepler_16
#
# [10 rows x 23 columns]

# %%
ff_new.shape
# Out:
# (14621, 23)

# %%
ff_new.to_csv("../results/2022_07_flares_vetted.csv",index=False)

# %% [markdown]
# # Vetting flares

# %%
# --------------------------------------
# select flares to vet
f = pd.read_csv("../results/2022_07_flares_vetted.csv")
# ff = ff[(ff.ID == string.split("_")[0]) & (ff.qcs==int(string.split("_")[1]))]
columns = ["TIC","qcs","mission","tstamp"]
name = list(f[f.real.isnull()].groupby(columns).indices)[0]
ff = f[f.real.isnull()].groupby(columns).get_group(name)
ID = ff.ID.iloc[0]
TIC, qcs, mission,tstamp = name
shape = f.shape[0]
print(f"Left to vet: {f[f.real.isnull()].shape[0]}")
print(name, ID)
print(ff[['tstart',"tstop","ID","TIC","qcs","real"]])

# ---------------------------------------
# view flares
# %matplotlib inline
for j, flare in ff.iloc[:].iterrows():
    ts, tf = flare.tstart, flare.tstop
    t0, t1, i = 1e5, 0., 0
    
    while (ts<t0) | (ts>t1):
        try:
            string = f"{ID}_{qcs:02}_altai_{i}"
            fff = fits.open(f"/media/ekaterina/USB DISK/lcs_w_phases/{tstamp}_{string}.fits")[1].data
        except FileNotFoundError:
            string = f"{TIC}_{qcs:02}_altai_0"
            fff = fits.open(f"/media/ekaterina/USB DISK/lcs_w_phases/{tstamp}_{string}.fits")[1].data
        t0,t1 = fff["time"][0],fff["time"][-1]
#         print(t0,ts,t1)
        i+=1
    plt.figure(figsize=(16,5))
    cap=.5
    
#     print(ts,tf)
    _ = fff[np.where((fff['time']>=ts-.1/cap) & (fff['time']<=tf+.1/cap))]
    med = np.median(_['flux'])
    plt.plot(_['time'], _['flux']/med, c="k")
    plt.xlim(_["time"][0],_["time"][-1])
    _ = fff[np.where((fff['time']>=ts-1e-8) & (fff['time']<=tf+1e-8))]
    plt.scatter(_['time'], _['flux']/med, c="r",zorder=10)

    plt.scatter(ts, flare.phase/5 + 1)
    plt.plot(_['time'], _['phase']/5 + 1, c="grey")
    plt.ylim(.99,flare.ampl_rec*1.5 +1)
    
plt.figure(figsize=(16,5))
plt.plot(fff["time"],fff["flux"],c="grey");
# plt.xlim(1590,1595)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-156-84a9ef84241d> in <module>
#       4 # ff = ff[(ff.ID == string.split("_")[0]) & (ff.qcs==int(string.split("_")[1]))]
#       5 columns = ["TIC","qcs","mission","tstamp"]
# ----> 6 name = list(f[f.real.isnull()].groupby(columns).indices)[0]
#       7 ff = f[f.real.isnull()].groupby(columns).get_group(name)
#       8 ID = ff.ID.iloc[0]
#
# IndexError: list index out of range

# %%
f.loc[ff.index,columns+["real"]]
# Out:
#              TIC  qcs mission      tstamp  real
# 14600  239291510   16  Kepler  2022_08_17   NaN

# %%
f.loc[ff.index,"real"] = 0

# %%
assert f.shape[0] == shape
f.to_csv("../results/2022_07_flares_vetted.csv",index=False)

# %% [markdown]
# # HAT-P-11, Kepler-34, Kepler-63

# %%
f = fits.open(f"/media/ekaterina/USB DISK/lcs_w_phases/2022_07_30_146520535_32_altai_0.fits")[1].data

# %%
f['time'][0], f['time'][-1]

# %%
T = f['time'][0] 

med = np.median(f['flux'])
for x in np.arange(20,30,0.5):
    
    plt.figure(figsize=(16,5))
    plt.plot(f['time'], f['flux']/med, c="grey")
    t0, t1 = T+x,T + 0.5 + x
    plt.xlim(t0,t1)
    plt.plot(f["time"],f["phase"])
    fid = np.where((f["time"] > t0) & (f["time"] < t1))[0]
    if len(fid)==0:
        continue
#     plt.plot(f['time'], f['cadenceno'], c="grey")
#     plt.ylim(np.min(f['cadenceno'][fid]), np.max(f['cadenceno'][fid]) )
    plt.ylim(max(np.min(f['flux'][fid]) / med, .95), 
             min(np.max(f['flux'][fid]) / med, 1.05))#np.min(f['flux'][fid] / med)

# %%
fid = np.where((f["time"] > 1476.5) & (f["time"] < 1476.55))[0]
f['phase'][fid]
