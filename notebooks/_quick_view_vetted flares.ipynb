# %%
from funcs.notebook import *

# %%
df =pd.read_csv("../results/2020_02_flares_vetted.csv")

# %%
df["real?"] = df["real?"].fillna(0).astype(float)

# %%
d = df[(df["real?"]==1.) & (df.ID!="AU Mic")]

# %%
d.shape[0]
# Out:
# 1249

# %%
d.groupby("ID").count().tstart.hist(bins=np.linspace(0,120,20), histtype="step",color="k")
plt.yscale("log")
plt.grid(False)
plt.xlabel("number of flares per star")
# Out:
# Text(0.5, 0, 'number of flares per star')

# %%
d.groupby("ID").count()
# Out:
#                          istart  istop  cstart  cstop  tstart  tstop  ed_rec  \
# ID
# 2MASS J01225093-2439505      42     42      42     42      42     42      42
# 2MASS J02192210-3925225       2      2       2      2       2      2       2
# 51 Eri                        1      1       1      1       1      1       1
# GJ 1061                       6      6       6      6       6      6       6
# GJ 1132                       1      1       1      1       1      1       1
# ...                         ...    ...     ...    ...     ...    ...     ...
# WASP-88                       1      1       1      1       1      1       1
# WASP-91                       2      2       2      2       2      2       2
# WASP-96                       1      1       1      1       1      1       1
# WASP-99                       1      1       1      1       1      1       1
# YZ Cet                       43     43      43     43      43     43      43
#
# ...

# %%
d.groupby(["ID", "qcs"]).count().sort_values(by="istart",ascending=False).head(20)
# Out:
#                              istart  istop  cstart  cstop  tstart  tstop  \
# ID                      qcs
# Proxima Cen             12       63     63      63     63      63     63
#                         11       47     47      47     47      47     47
# Kepler-1651             15       38     38      38     38      38     38
#                         14       35     35      35     35      35     35
# 2MASS J01225093-2439505 30       32     32      32     32      32     32
# Kepler-1627             15       28     28      28     28      28     28
# YZ Cet                  3        25     25      25     25      25     25
# Kepler-411              11       19     19      19     19      19     19
# YZ Cet                  30       18     18      18     18      18     18
# Kepler-411              13       17     17      17     17      17     17
# GJ 3323                 5        14     14      14     14      14     14
# ...

# %%
cf = df.groupby(["ID","qcs"]).first().reset_index()[["total_n_valid_data_points","qcs","mission"]]

# %%
DK1 = cf[(cf.mission=="Kepler")].total_n_valid_data_points.sum()/60/24
DT2 = cf[(cf.mission=="TESS") & (cf.qcs<27)].total_n_valid_data_points.sum()/30/24
DT20 = cf[(cf.mission=="TESS") & (cf.qcs>26)].total_n_valid_data_points.sum()/3/60/24

# %%
np.sum([DK1, DT2, DT20])/365.25
# Out:
# 545.8823662128933

# %%
df.loc[(df["real?"]==1.),"dur"].sum()
# Out:
# 15.225297967352654
